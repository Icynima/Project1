# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell'

# %%
df =pd.read_csv("fishdata.csv",error_bad_lines=False,index_col=False)
df
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             sl  year  month  day  hour  minute  second Carbon monoxide  \
# 0            1  2020    6.0   18    14      30      43             201
# 1            2  2020    6.0   18    14      30      48             201
# 2            3  2020    6.0   18    14      31       3             201
# 3            4  2020    6.0   18    14      31       8             201
# 4            5  2020    6.0   18    14      31      13             201
# ...        ...   ...    ...  ...   ...     ...     ...             ...
# 807403  807404  2020   10.0   19     8      24       0             201
# 807404  807405  2020   10.0   19     8      24       4             201
# 807405  807406  2020   10.0   19     8      24       8             201
# 807406  807407  2020   10.0   19     8      24      13            -168
# 807407  807408  2020   10.0   19     8      24      20             201
#
#         Internal Temparature  External Temparature  humidity  light intensity  \
# 0                       25.0                  29.0     95.00            27.19
# 1                       25.0                  29.0     95.00            27.19
# 2                       25.0                  29.0     95.00            27.19
# 3                       25.0                  29.0     95.00            27.19
# 4                       25.0                  29.0     95.00            27.25
# ...                      ...                   ...       ...              ...
# 807403                -165.0                  25.0     95.00            25.94
# 807404                -165.0                  25.0     95.00            25.94
# 807405                -167.0                  25.0     95.00            25.94
# 807406                  25.0                  95.0     25.94             4.18
# 807407                -169.0                  25.0     95.00            25.94
#
#            p
# 0       4.39
# 1       4.38
# 2       4.38
# 3       4.41
# 4       4.41
# ...      ...
# 807403  3.85
# 807404  3.84
# 807405  3.85
# 807406  3.85
# 807407  3.85
#
# [807408 rows x 13 columns]

# %%
df.head()
# Out:
#    sl  year  month  day  hour  minute  second Carbon monoxide  \
# 0   1  2020    6.0   18    14      30      43             201
# 1   2  2020    6.0   18    14      30      48             201
# 2   3  2020    6.0   18    14      31       3             201
# 3   4  2020    6.0   18    14      31       8             201
# 4   5  2020    6.0   18    14      31      13             201
#
#    Internal Temparature  External Temparature  humidity  light intensity     p
# 0                  25.0                  29.0      95.0            27.19  4.39
# 1                  25.0                  29.0      95.0            27.19  4.38
# 2                  25.0                  29.0      95.0            27.19  4.38
# 3                  25.0                  29.0      95.0            27.19  4.41
# 4                  25.0                  29.0      95.0            27.25  4.41

# %%
df.tail(10)
# Out:
#             sl  year  month  day  hour  minute  second Carbon monoxide  \
# 807398  807399  2020   10.0   19     8      23      39             201
# 807399  807400  2020   10.0   19     8      23      43             201
# 807400  807401  2020   10.0   19     8      23      47             201
# 807401  807402  2020   10.0   19     8      23      51             201
# 807402  807403  2020   10.0   19     8      23      55             201
# 807403  807404  2020   10.0   19     8      24       0             201
# 807404  807405  2020   10.0   19     8      24       4             201
# 807405  807406  2020   10.0   19     8      24       8             201
# 807406  807407  2020   10.0   19     8      24      13            -168
# 807407  807408  2020   10.0   19     8      24      20             201
#
#         Internal Temparature  External Temparature  humidity  light intensity  \
# 807398                -164.0                  25.0     95.00            25.94
# 807399                -164.0                  25.0     95.00            25.94
# 807400                -164.0                  25.0     95.00            25.94
# 807401                -164.0                  25.0     95.00            25.94
# 807402                -164.0                  25.0     95.00            25.94
# 807403                -165.0                  25.0     95.00            25.94
# 807404                -165.0                  25.0     95.00            25.94
# 807405                -167.0                  25.0     95.00            25.94
# 807406                  25.0                  95.0     25.94             4.18
# 807407                -169.0                  25.0     95.00            25.94
#
#            p
# 807398  3.84
# 807399  3.85
# 807400  3.85
# 807401  3.85
# 807402  3.84
# 807403  3.85
# 807404  3.84
# 807405  3.85
# 807406  3.85
# 807407  3.85

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807408 entries, 0 to 807407
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   sl                    807408 non-null  int64
#  1   year                  807408 non-null  int64
#  2   month                 807408 non-null  float64
#  3   day                   807408 non-null  int64
#  4   hour                  807408 non-null  int64
#  5   minute                807408 non-null  int64
#  6   second                807408 non-null  int64
#  7   Carbon monoxide       805710 non-null  object
#  8   Internal Temparature  807384 non-null  float64
#  9   External Temparature  807363 non-null  float64
#  10  humidity              807355 non-null  float64
#  11  light intensity       807355 non-null  float64
#  12  p                     802921 non-null  float64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 80.1+ MB

# %%
df.shape
# Out:
# (807408, 13)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (807408, 13)

# %%
df
# Out:
#             sl  year  month  day  hour  minute  second Carbon monoxide  \
# 0            1  2020    6.0   18    14      30      43             201
# 1            2  2020    6.0   18    14      30      48             201
# 2            3  2020    6.0   18    14      31       3             201
# 3            4  2020    6.0   18    14      31       8             201
# 4            5  2020    6.0   18    14      31      13             201
# ...        ...   ...    ...  ...   ...     ...     ...             ...
# 807403  807404  2020   10.0   19     8      24       0             201
# 807404  807405  2020   10.0   19     8      24       4             201
# 807405  807406  2020   10.0   19     8      24       8             201
# 807406  807407  2020   10.0   19     8      24      13            -168
# 807407  807408  2020   10.0   19     8      24      20             201
#
#         Internal Temparature  External Temparature  humidity  light intensity  \
# 0                       25.0                  29.0     95.00            27.19
# 1                       25.0                  29.0     95.00            27.19
# 2                       25.0                  29.0     95.00            27.19
# 3                       25.0                  29.0     95.00            27.19
# 4                       25.0                  29.0     95.00            27.25
# ...                      ...                   ...       ...              ...
# 807403                -165.0                  25.0     95.00            25.94
# 807404                -165.0                  25.0     95.00            25.94
# 807405                -167.0                  25.0     95.00            25.94
# 807406                  25.0                  95.0     25.94             4.18
# 807407                -169.0                  25.0     95.00            25.94
#
#            p
# 0       4.39
# 1       4.38
# 2       4.38
# 3       4.41
# 4       4.41
# ...      ...
# 807403  3.85
# 807404  3.84
# 807405  3.85
# 807406  3.85
# 807407  3.85
#
# [807408 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['sl', 'year', 'month', 'day', 'hour', 'minute', 'second',
#        'Carbon monoxide', 'Internal Temparature', 'External Temparature',
#        'humidity', 'light intensity', 'p'],
#       dtype='object')

# %%
df.columns=[col.upper() for col in df]
df.columns
# Out:
# Index(['SL', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'SECOND',
#        'CARBON MONOXIDE', 'INTERNAL TEMPARATURE', 'EXTERNAL TEMPARATURE',
#        'HUMIDITY', 'LIGHT INTENSITY', 'P'],
#       dtype='object')

# %%
df.rename(columns={
    'CARBON MONOXIDE':'CARBON_MONOXIDE',
    'INTERNAL TEMPARATURE': 'INTERNAL_TEMP',
    'EXTERNAL TEMPARATURE': 'EXTERNAL_TEMP',
    'P':'PH'
} ,inplace= True)

df.columns
# Out:
# Index(['SL', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'SECOND',
#        'CARBON_MONOXIDE', 'INTERNAL_TEMP', 'EXTERNAL_TEMP', 'HUMIDITY',
#        'LIGHT INTENSITY', 'PH'],
#       dtype='object')

# %%
df.isnull()
# Out:
#            SL   YEAR  MONTH    DAY   HOUR  MINUTE  SECOND  CARBON_MONOXIDE  \
# 0       False  False  False  False  False   False   False            False
# 1       False  False  False  False  False   False   False            False
# 2       False  False  False  False  False   False   False            False
# 3       False  False  False  False  False   False   False            False
# 4       False  False  False  False  False   False   False            False
# ...       ...    ...    ...    ...    ...     ...     ...              ...
# 807403  False  False  False  False  False   False   False            False
# 807404  False  False  False  False  False   False   False            False
# 807405  False  False  False  False  False   False   False            False
# 807406  False  False  False  False  False   False   False            False
# 807407  False  False  False  False  False   False   False            False
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY     PH
# 0               False          False     False            False  False
# 1               False          False     False            False  False
# 2               False          False     False            False  False
# 3               False          False     False            False  False
# 4               False          False     False            False  False
# ...               ...            ...       ...              ...    ...
# 807403          False          False     False            False  False
# 807404          False          False     False            False  False
# 807405          False          False     False            False  False
# 807406          False          False     False            False  False
# 807407          False          False     False            False  False
#
# [807408 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# SL                    0
# YEAR                  0
# MONTH                 0
# DAY                   0
# HOUR                  0
# MINUTE                0
# SECOND                0
# CARBON_MONOXIDE    1698
# INTERNAL_TEMP        24
# EXTERNAL_TEMP        45
# HUMIDITY             53
# LIGHT INTENSITY      53
# PH                 4487
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#             SL  YEAR  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0            1  2020    6.0   18    14      30      43             201
# 1            2  2020    6.0   18    14      30      48             201
# 2            3  2020    6.0   18    14      31       3             201
# 3            4  2020    6.0   18    14      31       8             201
# 4            5  2020    6.0   18    14      31      13             201
# ...        ...   ...    ...  ...   ...     ...     ...             ...
# 807403  807404  2020   10.0   19     8      24       0             201
# 807404  807405  2020   10.0   19     8      24       4             201
# 807405  807406  2020   10.0   19     8      24       8             201
# 807406  807407  2020   10.0   19     8      24      13            -168
# 807407  807408  2020   10.0   19     8      24      20             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0     95.00            27.19  4.39
# 1                25.0           29.0     95.00            27.19  4.38
# 2                25.0           29.0     95.00            27.19  4.38
# 3                25.0           29.0     95.00            27.19  4.41
# 4                25.0           29.0     95.00            27.25  4.41
# ...               ...            ...       ...              ...   ...
# 807403         -165.0           25.0     95.00            25.94  3.85
# 807404         -165.0           25.0     95.00            25.94  3.84
# 807405         -167.0           25.0     95.00            25.94  3.85
# 807406           25.0           95.0     25.94             4.18  3.85
# 807407         -169.0           25.0     95.00            25.94  3.85
#
# [801201 rows x 13 columns]

# %%
df
# Out:
#             SL  YEAR  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0            1  2020    6.0   18    14      30      43             201
# 1            2  2020    6.0   18    14      30      48             201
# 2            3  2020    6.0   18    14      31       3             201
# 3            4  2020    6.0   18    14      31       8             201
# 4            5  2020    6.0   18    14      31      13             201
# ...        ...   ...    ...  ...   ...     ...     ...             ...
# 807403  807404  2020   10.0   19     8      24       0             201
# 807404  807405  2020   10.0   19     8      24       4             201
# 807405  807406  2020   10.0   19     8      24       8             201
# 807406  807407  2020   10.0   19     8      24      13            -168
# 807407  807408  2020   10.0   19     8      24      20             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0     95.00            27.19  4.39
# 1                25.0           29.0     95.00            27.19  4.38
# 2                25.0           29.0     95.00            27.19  4.38
# 3                25.0           29.0     95.00            27.19  4.41
# 4                25.0           29.0     95.00            27.25  4.41
# ...               ...            ...       ...              ...   ...
# 807403         -165.0           25.0     95.00            25.94  3.85
# 807404         -165.0           25.0     95.00            25.94  3.84
# 807405         -167.0           25.0     95.00            25.94  3.85
# 807406           25.0           95.0     25.94             4.18  3.85
# 807407         -169.0           25.0     95.00            25.94  3.85
#
# [807408 rows x 13 columns]

# %%
inte=df['INTERNAL_TEMP']
inte
# Out:
# 0          25.0
# 1          25.0
# 2          25.0
# 3          25.0
# 4          25.0
#           ...
# 807403   -165.0
# 807404   -165.0
# 807405   -167.0
# 807406     25.0
# 807407   -169.0
# Name: INTERNAL_TEMP, Length: 807408, dtype: float64

# %%
inte_mean= inte.mean()
inte_mean
# Out:
# -64.87387671789384

# %%
ext=df['EXTERNAL_TEMP']
ext
# Out:
# 0         29.0
# 1         29.0
# 2         29.0
# 3         29.0
# 4         29.0
#           ...
# 807403    25.0
# 807404    25.0
# 807405    25.0
# 807406    95.0
# 807407    25.0
# Name: EXTERNAL_TEMP, Length: 807408, dtype: float64

# %%
ext_mean= ext.mean()
ext_mean
# Out:
# 30.8291025474291

# %%
ext.head(20)
# Out:
# 0     29.0
# 1     29.0
# 2     29.0
# 3     29.0
# 4     29.0
# 5     29.0
# 6     29.0
# 7     29.0
# 8     29.0
# 9     29.0
# 10    29.0
# 11    29.0
# 12    29.0
# 13    29.0
# 14    29.0
# 15    29.0
# 16    29.0
# 17    29.0
# 18    29.0
# 19    29.0
# Name: EXTERNAL_TEMP, dtype: float64

# %%
inte.fillna(inte_mean,inplace=True)

# %%
ext.fillna(ext_mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# SL                    0
# YEAR                  0
# MONTH                 0
# DAY                   0
# HOUR                  0
# MINUTE                0
# SECOND                0
# CARBON_MONOXIDE    1698
# INTERNAL_TEMP         0
# EXTERNAL_TEMP         0
# HUMIDITY             53
# LIGHT INTENSITY      53
# PH                 4487
# dtype: int64

# %%
df.dropna()
# Out:
#             SL  YEAR  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0            1  2020    6.0   18    14      30      43             201
# 1            2  2020    6.0   18    14      30      48             201
# 2            3  2020    6.0   18    14      31       3             201
# 3            4  2020    6.0   18    14      31       8             201
# 4            5  2020    6.0   18    14      31      13             201
# ...        ...   ...    ...  ...   ...     ...     ...             ...
# 807403  807404  2020   10.0   19     8      24       0             201
# 807404  807405  2020   10.0   19     8      24       4             201
# 807405  807406  2020   10.0   19     8      24       8             201
# 807406  807407  2020   10.0   19     8      24      13            -168
# 807407  807408  2020   10.0   19     8      24      20             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0     95.00            27.19  4.39
# 1                25.0           29.0     95.00            27.19  4.38
# 2                25.0           29.0     95.00            27.19  4.38
# 3                25.0           29.0     95.00            27.19  4.41
# 4                25.0           29.0     95.00            27.25  4.41
# ...               ...            ...       ...              ...   ...
# 807403         -165.0           25.0     95.00            25.94  3.85
# 807404         -165.0           25.0     95.00            25.94  3.84
# 807405         -167.0           25.0     95.00            25.94  3.85
# 807406           25.0           95.0     25.94             4.18  3.85
# 807407         -169.0           25.0     95.00            25.94  3.85
#
# [801201 rows x 13 columns]

# %%
df
# Out:
#             SL  YEAR  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0            1  2020    6.0   18    14      30      43             201
# 1            2  2020    6.0   18    14      30      48             201
# 2            3  2020    6.0   18    14      31       3             201
# 3            4  2020    6.0   18    14      31       8             201
# 4            5  2020    6.0   18    14      31      13             201
# ...        ...   ...    ...  ...   ...     ...     ...             ...
# 807403  807404  2020   10.0   19     8      24       0             201
# 807404  807405  2020   10.0   19     8      24       4             201
# 807405  807406  2020   10.0   19     8      24       8             201
# 807406  807407  2020   10.0   19     8      24      13            -168
# 807407  807408  2020   10.0   19     8      24      20             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0     95.00            27.19  4.39
# 1                25.0           29.0     95.00            27.19  4.38
# 2                25.0           29.0     95.00            27.19  4.38
# 3                25.0           29.0     95.00            27.19  4.41
# 4                25.0           29.0     95.00            27.25  4.41
# ...               ...            ...       ...              ...   ...
# 807403         -165.0           25.0     95.00            25.94  3.85
# 807404         -165.0           25.0     95.00            25.94  3.84
# 807405         -167.0           25.0     95.00            25.94  3.85
# 807406           25.0           95.0     25.94             4.18  3.85
# 807407         -169.0           25.0     95.00            25.94  3.85
#
# [807408 rows x 13 columns]

# %%
df.drop(['YEAR'], inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['SL', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'SECOND', 'CARBON_MONOXIDE',
#        'INTERNAL_TEMP', 'EXTERNAL_TEMP', 'HUMIDITY', 'LIGHT INTENSITY', 'PH'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# SL                 0
# MONTH              0
# DAY                0
# HOUR               0
# MINUTE             0
# SECOND             0
# CARBON_MONOXIDE    0
# INTERNAL_TEMP      0
# EXTERNAL_TEMP      0
# HUMIDITY           0
# LIGHT INTENSITY    0
# PH                 0
# dtype: int64

# %%
df.describe()
# Out:
#                   SL         MONTH            DAY           HOUR  \
# count  801201.000000  8.012010e+05  801201.000000  801201.000000
# mean   402631.379213  2.549652e+00      18.487088      11.777281
# std    233117.782065  2.536112e+03      26.770285       6.197226
# min         1.000000 -1.912020e+06       1.000000       0.000000
# 25%    200423.000000  7.000000e+00      13.000000       7.000000
# 50%    402264.000000  7.000000e+00      21.000000      12.000000
# 75%    604287.000000  8.000000e+00      26.000000      16.000000
# max    807408.000000  2.020000e+03   22020.000000      30.000000
#
#               MINUTE         SECOND  INTERNAL_TEMP  EXTERNAL_TEMP  \
# count  801201.000000  801201.000000  801201.000000  801201.000000
# mean       29.471778      29.496345     -64.753972      30.828929
# std        17.315794      17.320121      66.863206       5.697283
# min         0.000000       0.000000    -240.000000    -999.000000
# 25%        14.000000      14.000000    -139.000000      29.000000
# 50%        29.000000      29.000000     -50.000000      30.000000
# 75%        44.000000      45.000000     -19.000000      32.000000
# max        59.000000      59.000000     322.000000     310.000000
#
#             HUMIDITY  LIGHT INTENSITY             PH
# count  801201.000000    801201.000000  801201.000000
# mean       94.625533        28.490982      82.410639
# std         5.403919         2.602842    1636.901498
# min      -999.000000         2.970000       2.650000
# 25%        95.000000        27.060000       3.850000
# 50%        95.000000        28.250000       4.020000
# 75%        95.000000        30.250000       4.350000
# max        95.000000        95.000000   42020.000000

# %%
df.corr()
# Out:
#                        SL     MONTH       DAY      HOUR    MINUTE    SECOND  \
# SL               1.000000  0.002629 -0.052042  0.050131 -0.003034  0.000716
# MONTH            0.002629  1.000000  0.000751  0.000499  0.002309  0.000412
# DAY             -0.052042  0.000751  1.000000  0.000724 -0.001237 -0.001923
# HOUR             0.050131  0.000499  0.000724  1.000000 -0.010978 -0.000924
# MINUTE          -0.003034  0.002309 -0.001237 -0.010978  1.000000  0.000142
# SECOND           0.000716  0.000412 -0.001923 -0.000924  0.000142  1.000000
# INTERNAL_TEMP   -0.300681 -0.009600  0.037852 -0.024122  0.005327 -0.000480
# EXTERNAL_TEMP    0.021988  0.046772  0.074815 -0.011069  0.001723 -0.001548
# HUMIDITY        -0.045374  0.022377 -0.034688 -0.003618 -0.000397  0.000180
# LIGHT INTENSITY -0.260922 -0.048241  0.011091 -0.132297 -0.001022 -0.000190
# PH               0.023757  0.000098  0.000005  0.003020 -0.000236  0.001652
#
#                  INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY  \
# SL                   -0.300681       0.021988 -0.045374        -0.260922
# MONTH                -0.009600       0.046772  0.022377        -0.048241
# DAY                   0.037852       0.074815 -0.034688         0.011091
# HOUR                 -0.024122      -0.011069 -0.003618        -0.132297
# MINUTE                0.005327       0.001723 -0.000397        -0.001022
# SECOND               -0.000480      -0.001548  0.000180        -0.000190
# INTERNAL_TEMP         1.000000       0.212232 -0.098856         0.101534
# EXTERNAL_TEMP         0.212232       1.000000 -0.626827        -0.384212
# HUMIDITY             -0.098856      -0.626827  1.000000         0.626834
# LIGHT INTENSITY       0.101534      -0.384212  0.626834         1.000000
# PH                   -0.001591       0.002712  0.000068        -0.002942
#
#                        PH
# SL               0.023757
# MONTH            0.000098
# DAY              0.000005
# HOUR             0.003020
# MINUTE          -0.000236
# SECOND           0.001652
# INTERNAL_TEMP   -0.001591
# EXTERNAL_TEMP    0.002712
# HUMIDITY         0.000068
# LIGHT INTENSITY -0.002942
# PH               1.000000

# %%
df
# Out:
#             SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0            1    6.0   18    14      30      43             201
# 1            2    6.0   18    14      30      48             201
# 2            3    6.0   18    14      31       3             201
# 3            4    6.0   18    14      31       8             201
# 4            5    6.0   18    14      31      13             201
# ...        ...    ...  ...   ...     ...     ...             ...
# 807403  807404   10.0   19     8      24       0             201
# 807404  807405   10.0   19     8      24       4             201
# 807405  807406   10.0   19     8      24       8             201
# 807406  807407   10.0   19     8      24      13            -168
# 807407  807408   10.0   19     8      24      20             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0     95.00            27.19  4.39
# 1                25.0           29.0     95.00            27.19  4.38
# 2                25.0           29.0     95.00            27.19  4.38
# 3                25.0           29.0     95.00            27.19  4.41
# 4                25.0           29.0     95.00            27.25  4.41
# ...               ...            ...       ...              ...   ...
# 807403         -165.0           25.0     95.00            25.94  3.85
# 807404         -165.0           25.0     95.00            25.94  3.84
# 807405         -167.0           25.0     95.00            25.94  3.85
# 807406           25.0           95.0     25.94             4.18  3.85
# 807407         -169.0           25.0     95.00            25.94  3.85
#
# [801201 rows x 12 columns]

# %%
df_subset = df.iloc[5:20]

df_subset
# Out:
#     SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 5    6    6.0   18    14      31      23             201           25.0
# 6    7    6.0   18    14      31      28             201           25.0
# 7    8    6.0   18    14      31      33             201           25.0
# 8    9    6.0   18    14      31      43             200           26.0
# 9   10    6.0   18    14      31      48             200           26.0
# 10  11    6.0   18    14      31      53             200           26.0
# 11  12    6.0   18    14      31      58             200           27.0
# 12  13    6.0   18    14      32       8             200           26.0
# 13  14    6.0   18    14      32      13             200           26.0
# 14  15    6.0   18    14      32      18             200           26.0
# 15  16    6.0   18    14      32      28             199           27.0
# 16  17    6.0   18    14      32      33             199           27.0
# 17  18    6.0   18    14      32      38             200           27.0
# 18  19    6.0   18    14      32      48             199           27.0
# 19  20    6.0   18    14      32      53             199           27.0
#
#     EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 5            29.0      95.0            27.19  4.38
# 6            29.0      95.0            27.19  4.38
# 7            29.0      95.0            27.19  4.41
# 8            29.0      95.0            27.19  4.39
# 9            29.0      95.0            27.19  4.39
# 10           29.0      95.0            27.25  4.38
# 11           29.0      95.0            27.25  4.39
# 12           29.0      95.0            27.25  4.39
# 13           29.0      95.0            27.19  4.41
# 14           29.0      95.0            27.25  4.39
# 15           29.0      95.0            27.25  4.41
# 16           29.0      95.0            27.19  4.43
# 17           29.0      95.0            27.19  4.42
# 18           29.0      95.0            27.19  4.43
# 19           29.0      95.0            27.19  4.44

# %%
df.HOUR.iloc[12]
# Out:
# 14

# %%
cond = (df['MONTH'] == 10)

cond.head(100)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: MONTH, Length: 100, dtype: bool

# %%
df[df['MONTH'] == 10].head(100)
# Out:
#             SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 764522  764523   10.0    1     8      11      47             197
# 764523  764524   10.0    1     8      11      52             197
# 764524  764525   10.0    1     8      11      56             198
# 764525  764526   10.0    1     8      12       0             197
# 764526  764527   10.0    1     8      12       4             197
# ...        ...    ...  ...   ...     ...     ...             ...
# 764618  764619   10.0    1     8      19       2             195
# 764619  764620   10.0    1     8      19       6             196
# 764620  764621   10.0    1     8      19      10             195
# 764621  764622   10.0    1     8      19      14             196
# 764622  764623   10.0    1     8      19      19             196
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 764522         -158.0           29.0      95.0            29.19  3.93
# 764523         -157.0           29.0      95.0            29.19  3.94
# 764524         -159.0           29.0      95.0            29.19  3.94
# 764525         -157.0           29.0      95.0            29.19  3.94
# 764526         -159.0           29.0      95.0            29.19  3.94
# ...               ...            ...       ...              ...   ...
# 764618         -159.0           29.0      95.0            29.06  3.93
# 764619         -159.0           29.0      95.0            29.06  3.93
# 764620         -157.0           29.0      95.0            29.06  3.94
# 764621         -158.0           29.0      95.0            29.06  3.93
# 764622         -159.0           29.0      95.0            29.06  3.94
#
# [100 rows x 12 columns]

# %%
df[df['HOUR'] == 14].head(100)
# Out:
#      SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 0     1    6.0   18    14      30      43             201           25.0
# 1     2    6.0   18    14      30      48             201           25.0
# 2     3    6.0   18    14      31       3             201           25.0
# 3     4    6.0   18    14      31       8             201           25.0
# 4     5    6.0   18    14      31      13             201           25.0
# ..  ...    ...  ...   ...     ...     ...             ...            ...
# 95   96    6.0   18    14      41       8             200           28.0
# 96   97    6.0   18    14      41      13             200           27.0
# 97   98    6.0   18    14      41      18             200           28.0
# 98   99    6.0   18    14      41      28             200           27.0
# 99  100    6.0   18    14      41      33             200           27.0
#
#     EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0            29.0      95.0            27.19  4.39
# 1            29.0      95.0            27.19  4.38
# 2            29.0      95.0            27.19  4.38
# 3            29.0      95.0            27.19  4.41
# 4            29.0      95.0            27.25  4.41
# ..            ...       ...              ...   ...
# 95           29.0      95.0            27.25  4.39
# 96           29.0      95.0            27.25  4.42
# 97           29.0      95.0            27.25  4.40
# 98           29.0      95.0            27.25  4.39
# 99           29.0      95.0            27.25  4.39
#
# [100 rows x 12 columns]

# %%
df[df['HUMIDITY'] >= 70].head(10)
# Out:
#    SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 0   1    6.0   18    14      30      43             201           25.0
# 1   2    6.0   18    14      30      48             201           25.0
# 2   3    6.0   18    14      31       3             201           25.0
# 3   4    6.0   18    14      31       8             201           25.0
# 4   5    6.0   18    14      31      13             201           25.0
# 5   6    6.0   18    14      31      23             201           25.0
# 6   7    6.0   18    14      31      28             201           25.0
# 7   8    6.0   18    14      31      33             201           25.0
# 8   9    6.0   18    14      31      43             200           26.0
# 9  10    6.0   18    14      31      48             200           26.0
#
#    EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0           29.0      95.0            27.19  4.39
# 1           29.0      95.0            27.19  4.38
# 2           29.0      95.0            27.19  4.38
# 3           29.0      95.0            27.19  4.41
# 4           29.0      95.0            27.25  4.41
# 5           29.0      95.0            27.19  4.38
# 6           29.0      95.0            27.19  4.38
# 7           29.0      95.0            27.19  4.41
# 8           29.0      95.0            27.19  4.39
# 9           29.0      95.0            27.19  4.39

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 801201 entries, 0 to 807407
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SL               801201 non-null  int64
#  1   MONTH            801201 non-null  float64
#  2   DAY              801201 non-null  int64
#  3   HOUR             801201 non-null  int64
#  4   MINUTE           801201 non-null  int64
#  5   SECOND           801201 non-null  int64
#  6   CARBON_MONOXIDE  801201 non-null  object
#  7   INTERNAL_TEMP    801201 non-null  float64
#  8   EXTERNAL_TEMP    801201 non-null  float64
#  9   HUMIDITY         801201 non-null  float64
#  10  LIGHT INTENSITY  801201 non-null  float64
#  11  PH               801201 non-null  float64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 79.5+ MB

# %%
df[(df['INTERNAL_TEMP'] == 40) | (df['EXTERNAL_TEMP'] == 40)].head()
# Out:
#             SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 24687    24688    6.0   20    11       8      22             184
# 24691    24692    6.0   20    11       8      47             184
# 24693    24694    6.0   20    11       9       2             185
# 278592  278593    7.0   17    16       4       0             216
# 278596  278597    7.0   17    16       4      20             183
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 24687            40.0           31.0      95.0            29.06  4.66
# 24691            40.0           31.0      95.0            29.06  4.66
# 24693            40.0           31.0      95.0            29.00  4.64
# 278592           40.0           31.0      95.0            29.31  4.15
# 278596           40.0           31.0      95.0            29.31  4.14

# %%
df[(df['INTERNAL_TEMP'] == 40) | (df['EXTERNAL_TEMP'] == 40) & (df['LIGHT INTENSITY']==40)].tail()
# Out:
#             SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 622038  622039    8.0   14    10       8      47             201
# 622039  622040    8.0   14    10       8      51             201
# 622040  622041    8.0   14    10       8      55             201
# 622045  622046    8.0   14    10       9      16             201
# 622046  622047    8.0   14    10       9      20             202
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 622038           40.0           30.0      95.0            26.81  4.24
# 622039           40.0           30.0      95.0            26.81  4.26
# 622040           40.0           30.0      95.0            26.81  4.24
# 622045           40.0           30.0      95.0            26.81  4.24
# 622046           40.0           30.0      95.0            26.81  4.24

# %%
import matplotlib
from matplotlib import pyplot as plt

# %%
oct= df[df.MONTH == 10].head(500)
oct
# Out:
#             SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 764522  764523   10.0    1     8      11      47             197
# 764523  764524   10.0    1     8      11      52             197
# 764524  764525   10.0    1     8      11      56             198
# 764525  764526   10.0    1     8      12       0             197
# 764526  764527   10.0    1     8      12       4             197
# ...        ...    ...  ...   ...     ...     ...             ...
# 765022  765023   10.0    1     8      49      15             200
# 765023  765024   10.0    1     8      49      19             200
# 765024  765025   10.0    1     8      49      23             200
# 765025  765026   10.0    1     8      49      27             200
# 765026  765027   10.0    1     8      49      31             200
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 764522         -158.0           29.0      95.0            29.19  3.93
# 764523         -157.0           29.0      95.0            29.19  3.94
# 764524         -159.0           29.0      95.0            29.19  3.94
# 764525         -157.0           29.0      95.0            29.19  3.94
# 764526         -159.0           29.0      95.0            29.19  3.94
# ...               ...            ...       ...              ...   ...
# 765022         -159.0           28.0      95.0            28.44  3.94
# 765023         -159.0           28.0      95.0            28.44  3.94
# 765024         -159.0           28.0      95.0            28.44  3.94
# 765025         -159.0           28.0      95.0            28.44  3.94
# 765026         -159.0           28.0      95.0            28.44  3.94
#
# [500 rows x 12 columns]

# %%
july= df[df.MONTH == 7].head(500)
july
# Out:
#             SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 164534  164535    7.0    1     0       0       1             282
# 164535  164536    7.0    1     0       0      11             282
# 164536  164537    7.0    1     0       0      16             282
# 164537  164538    7.0    1     0       0      21             282
# 164538  164539    7.0    1     0       0      26             282
# ...        ...    ...  ...   ...     ...     ...             ...
# 165029  165030    7.0    1     0      53      42             281
# 165030  165031    7.0    1     0      53      47             281
# 165031  165032    7.0    1     0      53      57             281
# 165032  165033    7.0    1     0      54       2             281
# 165033  165034    7.0    1     0      54       7             281
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 164534         -100.0           31.0      95.0            30.25  4.67
# 164535         -204.0           31.0      95.0            30.19  4.65
# 164536         -215.0           31.0      95.0            30.25  4.67
# 164537         -195.0           31.0      95.0            30.19  4.67
# 164538         -161.0           31.0      95.0            30.19  4.67
# ...               ...            ...       ...              ...   ...
# 165029          -20.0           31.0      95.0            30.31  4.67
# 165030          -81.0           31.0      95.0            30.31  4.67
# 165031         -139.0           31.0      95.0            30.31  4.66
# 165032          -54.0           31.0      95.0            30.31  4.64
# 165033          -17.0           31.0      95.0            30.31  4.67
#
# [500 rows x 12 columns]

# %%
##plt.plot(df2.MONTH, df2.PH)
plt.plot(july.INTERNAL_TEMP, july.EXTERNAL_TEMP)
plt.plot(oct.INTERNAL_TEMP, oct.EXTERNAL_TEMP)
plt.legend(['july','oct'])
plt.xlabel('INTERNAL_TEMP')
plt.ylabel('EXTERNAL_TEMP')
plt.show()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
df2=df.head(1000)
df2
# Out:
#        SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 0       1    6.0   18    14      30      43             201           25.0
# 1       2    6.0   18    14      30      48             201           25.0
# 2       3    6.0   18    14      31       3             201           25.0
# 3       4    6.0   18    14      31       8             201           25.0
# 4       5    6.0   18    14      31      13             201           25.0
# ..    ...    ...  ...   ...     ...     ...             ...            ...
# 995   996    6.0   18    16      18      39             196           31.0
# 996   997    6.0   18    16      18      49             196           31.0
# 997   998    6.0   18    16      18      54             196           31.0
# 998   999    6.0   18    16      18      59             196           31.0
# 999  1000    6.0   18    16      19       9             196           31.0
#
#      EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0             29.0      95.0            27.19  4.39
# 1             29.0      95.0            27.19  4.38
# 2             29.0      95.0            27.19  4.38
# 3             29.0      95.0            27.19  4.41
# 4             29.0      95.0            27.25  4.41
# ..             ...       ...              ...   ...
# 995           28.0      95.0            27.19  4.43
# 996           28.0      95.0            27.19  4.42
# 997           28.0      95.0            27.19  4.46
# 998           28.0      95.0            27.19  4.42
# 999           28.0      95.0            27.19  4.45
#
# [1000 rows x 12 columns]

# %%
plt.plot(df2.PH, df2.CARBON_MONOXIDE)
plt.plot(df2.PH, df2.HUMIDITY)
plt.legend(['CARBON_MONOXIDE','Humidity '])
plt.xlabel('PH')
plt.ylabel('Humidity & Carbon-monoxide')
plt.show()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
df['PH'].min()
# Out:
# 2.65

# %%
df['PH'].max()
# Out:
# 42020.0

# %%
df['PH'].mean()
# Out:
# 82.41063901884108

# %%
df['PH'].std()
# Out:
# 1636.9014979450003

# %%
df['PH'].count()
# Out:
# 801201

# %%
df
# Out:
#             SL  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0            1    6.0   18    14      30      43             201
# 1            2    6.0   18    14      30      48             201
# 2            3    6.0   18    14      31       3             201
# 3            4    6.0   18    14      31       8             201
# 4            5    6.0   18    14      31      13             201
# ...        ...    ...  ...   ...     ...     ...             ...
# 807403  807404   10.0   19     8      24       0             201
# 807404  807405   10.0   19     8      24       4             201
# 807405  807406   10.0   19     8      24       8             201
# 807406  807407   10.0   19     8      24      13            -168
# 807407  807408   10.0   19     8      24      20             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0     95.00            27.19  4.39
# 1                25.0           29.0     95.00            27.19  4.38
# 2                25.0           29.0     95.00            27.19  4.38
# 3                25.0           29.0     95.00            27.19  4.41
# 4                25.0           29.0     95.00            27.25  4.41
# ...               ...            ...       ...              ...   ...
# 807403         -165.0           25.0     95.00            25.94  3.85
# 807404         -165.0           25.0     95.00            25.94  3.84
# 807405         -167.0           25.0     95.00            25.94  3.85
# 807406           25.0           95.0     25.94             4.18  3.85
# 807407         -169.0           25.0     95.00            25.94  3.85
#
# [801201 rows x 12 columns]

# %%
df.plot(kind='line',x='SL',y='CARBON_MONOXIDE')
df.plot(kind='line',x='SL',y='INTERNAL_TEMP', color='red')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-275-8c6a7dfcb071> in <module>
# ----> 1 df.plot(kind='line',x='SL',y='CARBON_MONOXIDE')
#       2 df.plot(kind='line',x='SL',y='INTERNAL_TEMP', color='red')
#       3
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
df.plot(x ='SL', y='CARBON_MONOXIDE', kind = 'scatter')
df.plot(x ='SL', y='INTERNAL_TEMP', kind = 'scatter')
df.plot(x ='SL', y='EXTERNAL_TEMP', kind = 'scatter')
df.plot(x ='SL', y='HUMIDITY', kind = 'scatter')
df.plot(x ='SL', y='LIGHT INTENSITY', kind = 'scatter')
plt.show()
