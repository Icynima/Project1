# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell'

# %%
df =pd.read_csv("fishdata.csv",error_bad_lines=False,index_col=False)
df
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           year  month  day  hour  minute  second Carbon monoxide  \
# 0       2020.0    6.0   18    14    30.0    43.0             201
# 1       2020.0    6.0   18    14    30.0    48.0             201
# 2       2020.0    6.0   18    14    31.0     3.0             201
# 3       2020.0    6.0   18    14    31.0     8.0             201
# 4       2020.0    6.0   18    14    31.0    13.0             201
# ...        ...    ...  ...   ...     ...     ...             ...
# 811941  2020.0   10.0   19     8    24.0     4.0             201
# 811942  2020.0   10.0   19     8    24.0     8.0             201
# 811943  2020.0   10.0   19     8    24.0    13.0            -168
# 811944  2020.0   10.0   19     8    24.0    16.0             201
# ...

# %%
df.head(100)
# Out:
#       year  month  day  hour  minute  second Carbon monoxide  \
# 0   2020.0    6.0   18    14    30.0    43.0             201
# 1   2020.0    6.0   18    14    30.0    48.0             201
# 2   2020.0    6.0   18    14    31.0     3.0             201
# 3   2020.0    6.0   18    14    31.0     8.0             201
# 4   2020.0    6.0   18    14    31.0    13.0             201
# ..     ...    ...  ...   ...     ...     ...             ...
# 95  2020.0    6.0   18    14    41.0     8.0             200
# 96  2020.0    6.0   18    14    41.0    13.0             200
# 97  2020.0    6.0   18    14    41.0    18.0             200
# 98  2020.0    6.0   18    14    41.0    28.0             200
# 99  2020.0    6.0   18    14    41.0    33.0             200
#
#     Internal Temparature  External Temparature  humidity  light intensity  \
# 0                   25.0                  29.0      95.0            27.19
# 1                   25.0                  29.0      95.0            27.19
# ...

# %%
df.tail()
# Out:
#           year  month  day  hour  minute  second Carbon monoxide  \
# 811941  2020.0   10.0   19     8    24.0     4.0             201
# 811942  2020.0   10.0   19     8    24.0     8.0             201
# 811943  2020.0   10.0   19     8    24.0    13.0            -168
# 811944  2020.0   10.0   19     8    24.0    16.0             201
# 811945  2020.0   10.0   19     8    24.0    20.0             201
#
#         Internal Temparature  External Temparature  humidity  light intensity  \
# 811941                -165.0                  25.0     95.00            25.94
# 811942                -167.0                  25.0     95.00            25.94
# 811943                  25.0                  95.0     25.94             4.18
# 811944                -169.0                  25.0     95.00            25.94
# 811945                -169.0                  25.0     95.00            25.94
#
#           pH
# 811941  4.17
# 811942  4.19
# 811943   NaN
# 811944  4.17
# 811945  4.17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811946 entries, 0 to 811945
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   year                  811946 non-null  float64
#  1   month                 811946 non-null  float64
#  2   day                   811946 non-null  int64
#  3   hour                  811946 non-null  int64
#  4   minute                811946 non-null  float64
#  5   second                811946 non-null  float64
#  6   Carbon monoxide       810198 non-null  object
#  7   Internal Temparature  811872 non-null  float64
#  8   External Temparature  811851 non-null  float64
#  9   humidity              811843 non-null  float64
#  10  light intensity       811843 non-null  float64
#  11  pH                    807408 non-null  float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 74.3+ MB

# %%
df.shape
# Out:
# (811946, 12)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (811946, 12)

# %%
df
# Out:
#           year  month  day  hour  minute  second Carbon monoxide  \
# 0       2020.0    6.0   18    14    30.0    43.0             201
# 1       2020.0    6.0   18    14    30.0    48.0             201
# 2       2020.0    6.0   18    14    31.0     3.0             201
# 3       2020.0    6.0   18    14    31.0     8.0             201
# 4       2020.0    6.0   18    14    31.0    13.0             201
# ...        ...    ...  ...   ...     ...     ...             ...
# 811941  2020.0   10.0   19     8    24.0     4.0             201
# 811942  2020.0   10.0   19     8    24.0     8.0             201
# 811943  2020.0   10.0   19     8    24.0    13.0            -168
# 811944  2020.0   10.0   19     8    24.0    16.0             201
# 811945  2020.0   10.0   19     8    24.0    20.0             201
#
#         Internal Temparature  External Temparature  humidity  light intensity  \
# 0                       25.0                  29.0     95.00            27.19
# ...

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'hour', 'minute', 'second', 'Carbon monoxide',
#        'Internal Temparature', 'External Temparature', 'humidity',
#        'light intensity', 'pH'],
#       dtype='object')

# %%
df.columns=[col.upper() for col in df]
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'SECOND', 'CARBON MONOXIDE',
#        'INTERNAL TEMPARATURE', 'EXTERNAL TEMPARATURE', 'HUMIDITY',
#        'LIGHT INTENSITY', 'PH'],
#       dtype='object')

# %%
df.rename(columns={
    'CARBON MONOXIDE':'CARBON_MONOXIDE',
    'INTERNAL TEMPARATURE': 'INTERNAL_TEMP',
    'EXTERNAL TEMPARATURE': 'EXTERNAL_TEMP'
} ,inplace= True)

df.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'SECOND', 'CARBON_MONOXIDE',
#        'INTERNAL_TEMP', 'EXTERNAL_TEMP', 'HUMIDITY', 'LIGHT INTENSITY', 'PH'],
#       dtype='object')

# %%
df.isnull()
# Out:
#          YEAR  MONTH    DAY   HOUR  MINUTE  SECOND  CARBON_MONOXIDE  \
# 0       False  False  False  False   False   False            False
# 1       False  False  False  False   False   False            False
# 2       False  False  False  False   False   False            False
# 3       False  False  False  False   False   False            False
# 4       False  False  False  False   False   False            False
# ...       ...    ...    ...    ...     ...     ...              ...
# 811941  False  False  False  False   False   False            False
# 811942  False  False  False  False   False   False            False
# 811943  False  False  False  False   False   False            False
# 811944  False  False  False  False   False   False            False
# 811945  False  False  False  False   False   False            False
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY     PH
# 0               False          False     False            False  False
# ...

# %%
df.isnull().sum()
# Out:
# YEAR                  0
# MONTH                 0
# DAY                   0
# HOUR                  0
# MINUTE                0
# SECOND                0
# CARBON_MONOXIDE    1748
# INTERNAL_TEMP        74
# EXTERNAL_TEMP        95
# HUMIDITY            103
# LIGHT INTENSITY     103
# PH                 4538
# dtype: int64

# %%
df.dropna()
# Out:
#           YEAR  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0       2020.0    6.0   18    14    30.0    43.0             201
# 1       2020.0    6.0   18    14    30.0    48.0             201
# 2       2020.0    6.0   18    14    31.0     3.0             201
# 3       2020.0    6.0   18    14    31.0     8.0             201
# 4       2020.0    6.0   18    14    31.0    13.0             201
# ...        ...    ...  ...   ...     ...     ...             ...
# 811940  2020.0   10.0   19     8    24.0     0.0             201
# 811941  2020.0   10.0   19     8    24.0     4.0             201
# 811942  2020.0   10.0   19     8    24.0     8.0             201
# 811944  2020.0   10.0   19     8    24.0    16.0             201
# 811945  2020.0   10.0   19     8    24.0    20.0             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0      95.0            27.19  4.39
# ...

# %%
df.dropna(axis=0)
# Out:
#           YEAR  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0       2020.0    6.0   18    14    30.0    43.0             201
# 1       2020.0    6.0   18    14    30.0    48.0             201
# 2       2020.0    6.0   18    14    31.0     3.0             201
# 3       2020.0    6.0   18    14    31.0     8.0             201
# 4       2020.0    6.0   18    14    31.0    13.0             201
# ...        ...    ...  ...   ...     ...     ...             ...
# 811940  2020.0   10.0   19     8    24.0     0.0             201
# 811941  2020.0   10.0   19     8    24.0     4.0             201
# 811942  2020.0   10.0   19     8    24.0     8.0             201
# 811944  2020.0   10.0   19     8    24.0    16.0             201
# 811945  2020.0   10.0   19     8    24.0    20.0             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0      95.0            27.19  4.39
# ...

# %%
inte=df['INTERNAL_TEMP']
inte
# Out:
# 0          25.0
# 1          25.0
# 2          25.0
# 3          25.0
# 4          25.0
#           ...
# 811941   -165.0
# 811942   -167.0
# 811943     25.0
# 811944   -169.0
# 811945   -169.0
# Name: INTERNAL_TEMP, Length: 811946, dtype: float64

# %%
inte_mean= inte.mean()
inte_mean
# Out:
# -65.00106184226085

# %%
ext=df['EXTERNAL_TEMP']
ext
# Out:
# 0         29.0
# 1         29.0
# 2         29.0
# 3         29.0
# 4         29.0
#           ...
# 811941    25.0
# 811942    25.0
# 811943    95.0
# 811944    25.0
# 811945    25.0
# Name: EXTERNAL_TEMP, Length: 811946, dtype: float64

# %%
ext_mean= ext.mean()
ext_mean
# Out:
# 30.82704919991476

# %%
ext.head(20)
# Out:
# 0     29.0
# 1     29.0
# 2     29.0
# 3     29.0
# 4     29.0
# 5     29.0
# 6     29.0
# 7     29.0
# 8     29.0
# 9     29.0
# 10    29.0
# 11    29.0
# 12    29.0
# 13    29.0
# 14    29.0
# 15    29.0
# 16    29.0
# 17    29.0
# 18    29.0
# 19    29.0
# Name: EXTERNAL_TEMP, dtype: float64

# %%
inte.fillna(inte_mean,inplace=True)

# %%
ext.fillna(ext_mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# YEAR                  0
# MONTH                 0
# DAY                   0
# HOUR                  0
# MINUTE                0
# SECOND                0
# CARBON_MONOXIDE    1748
# INTERNAL_TEMP         0
# EXTERNAL_TEMP         0
# HUMIDITY            103
# LIGHT INTENSITY     103
# PH                 4538
# dtype: int64

# %%
df
# Out:
#           YEAR  MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  \
# 0       2020.0    6.0   18    14    30.0    43.0             201
# 1       2020.0    6.0   18    14    30.0    48.0             201
# 2       2020.0    6.0   18    14    31.0     3.0             201
# 3       2020.0    6.0   18    14    31.0     8.0             201
# 4       2020.0    6.0   18    14    31.0    13.0             201
# ...        ...    ...  ...   ...     ...     ...             ...
# 811941  2020.0   10.0   19     8    24.0     4.0             201
# 811942  2020.0   10.0   19     8    24.0     8.0             201
# 811943  2020.0   10.0   19     8    24.0    13.0            -168
# 811944  2020.0   10.0   19     8    24.0    16.0             201
# 811945  2020.0   10.0   19     8    24.0    20.0             201
#
#         INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0                25.0           29.0     95.00            27.19  4.39
# ...

# %%
df.drop(['YEAR'], inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['MONTH', 'DAY', 'HOUR', 'MINUTE', 'SECOND', 'CARBON_MONOXIDE',
#        'INTERNAL_TEMP', 'EXTERNAL_TEMP', 'HUMIDITY', 'LIGHT INTENSITY', 'PH'],
#       dtype='object')

# %%
df.loc[100]
# Out:
# MONTH                  6
# DAY                   18
# HOUR                  14
# MINUTE                41
# SECOND                38
# CARBON_MONOXIDE      200
# INTERNAL_TEMP         27
# EXTERNAL_TEMP         29
# HUMIDITY              95
# LIGHT INTENSITY    27.25
# PH                  4.43
# Name: 100, dtype: object

# %%
df.loc[2000]
# Out:
# MONTH                  6
# DAY                   18
# HOUR                  18
# MINUTE                 7
# SECOND                31
# CARBON_MONOXIDE      220
# INTERNAL_TEMP        -14
# EXTERNAL_TEMP         29
# HUMIDITY              95
# LIGHT INTENSITY    27.25
# PH                  4.17
# Name: 2000, dtype: object

# %%
df.describe()
# Out:
#               MONTH            DAY           HOUR         MINUTE  \
# count  8.119460e+05  811946.000000  811946.000000  811946.000000
# mean   2.617098e+00      18.485033      11.785307      29.477050
# std    2.519275e+03      26.612144       6.223211      17.316265
# min   -1.912020e+06       1.000000       0.000000       0.000000
# 25%    7.000000e+00      13.000000       7.000000      14.000000
# 50%    7.000000e+00      21.000000      12.000000      29.000000
# 75%    8.000000e+00      26.000000      16.000000      44.000000
# max    2.020000e+03   22020.000000      95.000000      59.000000
#
#               SECOND  INTERNAL_TEMP  EXTERNAL_TEMP       HUMIDITY  \
# count  811946.000000  811946.000000  811946.000000  811843.000000
# mean       29.496661     -65.001062      30.827049      94.627387
# std        17.320485      66.950774       5.682456       5.387394
# min         0.000000    -240.000000    -999.000000    -999.000000
# ...

# %%
df.corr()
# Out:
#                     MONTH       DAY      HOUR    MINUTE    SECOND  \
# MONTH            1.000000  0.000748  0.000475  0.002295  0.000412
# DAY              0.000748  1.000000  0.001012 -0.001276 -0.001936
# HOUR             0.000475  0.001012  1.000000 -0.011219 -0.002052
# MINUTE           0.002295 -0.001276 -0.011219  1.000000  0.000196
# SECOND           0.000412 -0.001936 -0.002052  0.000196  1.000000
# INTERNAL_TEMP   -0.009536  0.038285 -0.024837  0.005199 -0.000161
# EXTERNAL_TEMP    0.046580  0.074758 -0.011256  0.001795 -0.001421
# HUMIDITY         0.022299 -0.034530 -0.003427 -0.000521  0.000177
# LIGHT INTENSITY -0.047976  0.011549 -0.132460 -0.001197  0.000061
# PH               0.000070  0.000236  0.001864 -0.001068 -0.001190
#
#                  INTERNAL_TEMP  EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY  \
# MONTH                -0.009536       0.046580  0.022299        -0.047976
# DAY                   0.038285       0.074758 -0.034530         0.011549
# ...

# %%
df
# Out:
#         MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 0         6.0   18    14    30.0    43.0             201           25.0
# 1         6.0   18    14    30.0    48.0             201           25.0
# 2         6.0   18    14    31.0     3.0             201           25.0
# 3         6.0   18    14    31.0     8.0             201           25.0
# 4         6.0   18    14    31.0    13.0             201           25.0
# ...       ...  ...   ...     ...     ...             ...            ...
# 811941   10.0   19     8    24.0     4.0             201         -165.0
# 811942   10.0   19     8    24.0     8.0             201         -167.0
# 811943   10.0   19     8    24.0    13.0            -168           25.0
# 811944   10.0   19     8    24.0    16.0             201         -169.0
# 811945   10.0   19     8    24.0    20.0             201         -169.0
#
#         EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# ...

# %%
df_subset = df.iloc[5:20]

df_subset
# Out:
#     MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 5     6.0   18    14    31.0    23.0             201           25.0
# 6     6.0   18    14    31.0    28.0             201           25.0
# 7     6.0   18    14    31.0    33.0             201           25.0
# 8     6.0   18    14    31.0    43.0             200           26.0
# 9     6.0   18    14    31.0    48.0             200           26.0
# 10    6.0   18    14    31.0    53.0             200           26.0
# 11    6.0   18    14    31.0    58.0             200           27.0
# 12    6.0   18    14    32.0     8.0             200           26.0
# 13    6.0   18    14    32.0    13.0             200           26.0
# 14    6.0   18    14    32.0    18.0             200           26.0
# 15    6.0   18    14    32.0    28.0             199           27.0
# 16    6.0   18    14    32.0    33.0             199           27.0
# 17    6.0   18    14    32.0    38.0             200           27.0
# ...

# %%
df.MONTH.iloc[12]
# Out:
# 6.0

# %%
cond = (df['MONTH'] == 11)

cond.head(100)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: MONTH, Length: 100, dtype: bool

# %%
df[df['MONTH'] == 10].head(100)
# Out:
#         MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 768575   10.0    1     8    11.0    47.0             197         -158.0
# 768576   10.0    1     8    11.0    52.0             197         -157.0
# 768577   10.0    1     8    11.0    56.0             198         -159.0
# 768578   10.0    1     8    12.0     0.0             197         -157.0
# 768579   10.0    1     8    12.0     4.0             197         -159.0
# ...       ...  ...   ...     ...     ...             ...            ...
# 768670   10.0    1     8    18.0    58.0             195         -158.0
# 768671   10.0    1     8    19.0     2.0             195         -159.0
# 768672   10.0    1     8    19.0     6.0             196         -159.0
# 768673   10.0    1     8    19.0    10.0             195         -157.0
# 768674   10.0    1     8    19.0    14.0             196         -158.0
#
#         EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# ...

# %%
df[df['HOUR'] == 14].head(100)
# Out:
#     MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 0     6.0   18    14    30.0    43.0             201           25.0
# 1     6.0   18    14    30.0    48.0             201           25.0
# 2     6.0   18    14    31.0     3.0             201           25.0
# 3     6.0   18    14    31.0     8.0             201           25.0
# 4     6.0   18    14    31.0    13.0             201           25.0
# ..    ...  ...   ...     ...     ...             ...            ...
# 95    6.0   18    14    41.0     8.0             200           28.0
# 96    6.0   18    14    41.0    13.0             200           27.0
# 97    6.0   18    14    41.0    18.0             200           28.0
# 98    6.0   18    14    41.0    28.0             200           27.0
# 99    6.0   18    14    41.0    33.0             200           27.0
#
#     EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0            29.0      95.0            27.19  4.39
# ...

# %%
df[df['HUMIDITY'] >= 70].head(10)
# Out:
#    MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 0    6.0   18    14    30.0    43.0             201           25.0
# 1    6.0   18    14    30.0    48.0             201           25.0
# 2    6.0   18    14    31.0     3.0             201           25.0
# 3    6.0   18    14    31.0     8.0             201           25.0
# 4    6.0   18    14    31.0    13.0             201           25.0
# 5    6.0   18    14    31.0    23.0             201           25.0
# 6    6.0   18    14    31.0    28.0             201           25.0
# 7    6.0   18    14    31.0    33.0             201           25.0
# 8    6.0   18    14    31.0    43.0             200           26.0
# 9    6.0   18    14    31.0    48.0             200           26.0
#
#    EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0           29.0      95.0            27.19  4.39
# 1           29.0      95.0            27.19  4.38
# 2           29.0      95.0            27.19  4.38
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 811946 entries, 0 to 811945
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   MONTH            811946 non-null  float64
#  1   DAY              811946 non-null  int64
#  2   HOUR             811946 non-null  int64
#  3   MINUTE           811946 non-null  float64
#  4   SECOND           811946 non-null  float64
#  5   CARBON_MONOXIDE  810198 non-null  object
#  6   INTERNAL_TEMP    811946 non-null  float64
#  7   EXTERNAL_TEMP    811946 non-null  float64
#  8   HUMIDITY         811843 non-null  float64
#  9   LIGHT INTENSITY  811843 non-null  float64
#  10  PH               807408 non-null  float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 114.3+ MB

# %%
df[(df['INTERNAL_TEMP'] == 40) | (df['EXTERNAL_TEMP'] == 40)].head()
# Out:
#         MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 24705     6.0   20    11     8.0    22.0             184           40.0
# 24709     6.0   20    11     8.0    47.0             184           40.0
# 24711     6.0   20    11     9.0     2.0             185           40.0
# 278954    7.0   17    16     4.0     0.0             216           40.0
# 278958    7.0   17    16     4.0    20.0             183           40.0
#
#         EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 24705            31.0      95.0            29.06  4.70
# 24709            31.0      95.0            29.06  4.70
# 24711            31.0      95.0            29.00  4.66
# 278954           31.0      95.0            29.31  3.85
# 278958           31.0      95.0            29.31  3.90

# %%
df[(df['INTERNAL_TEMP'] == 40) | (df['EXTERNAL_TEMP'] == 40) & (df['LIGHT INTENSITY']==40)].tail()
# Out:
#         MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 624402    8.0   14    10     8.0    47.0             201           40.0
# 624403    8.0   14    10     8.0    51.0             201           40.0
# 624404    8.0   14    10     8.0    55.0             201           40.0
# 624409    8.0   14    10     9.0    16.0             201           40.0
# 624410    8.0   14    10     9.0    20.0             202           40.0
#
#         EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 624402           30.0      95.0            26.81  4.07
# 624403           30.0      95.0            26.81  4.07
# 624404           30.0      95.0            26.81  4.07
# 624409           30.0      95.0            26.81  4.07
# 624410           30.0      95.0            26.81  4.06

# %%
import matplotlib
from matplotlib import pyplot as plt

# %%
plt.plot(df.MONTH,df.PH)
plt.show
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\Dell\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
nov= df[df.MONTH == 9].head(50)
nov
# Out:
#         MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 675549    9.0    1     8    53.0    14.0             182         -160.0
# 675550    9.0    1     8    53.0    18.0             182         -161.0
# 675551    9.0    1     8    53.0    22.0             182         -160.0
# 675552    9.0    1     8    53.0    27.0             182         -160.0
# 675553    9.0    1     8    53.0    31.0             182         -161.0
# 675554    9.0    1     8    53.0    35.0             182         -160.0
# 675555    9.0    1     8    53.0    39.0             182         -160.0
# 675556    9.0    1     8    53.0    43.0             182         -160.0
# 675557    9.0    1     8    53.0    47.0             182         -160.0
# 675558    9.0    1     8    53.0    55.0             182         -160.0
# 675559    9.0    1     8    53.0    59.0             182         -160.0
# 675560    9.0    1     8    54.0     3.0             182         -160.0
# ...

# %%
july= df[df.MONTH == 7].head(50)
july
# Out:
#         MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 164604    7.0    1     0     0.0     1.0             282         -100.0
# 164605    7.0    1     0     0.0    11.0             282         -204.0
# 164606    7.0    1     0     0.0    16.0             282         -215.0
# 164607    7.0    1     0     0.0    21.0             282         -195.0
# 164608    7.0    1     0     0.0    26.0             282         -161.0
# 164609    7.0    1     0     0.0    36.0             282         -138.0
# 164610    7.0    1     0     0.0    41.0             282         -176.0
# 164611    7.0    1     0     0.0    46.0             282         -211.0
# 164612    7.0    1     0     0.0    56.0             282          -28.0
# 164613    7.0    1     0     1.0     1.0             282          -44.0
# 164614    7.0    1     0     1.0     6.0             282         -160.0
# 164615    7.0    1     0     1.0    16.0             281         -180.0
# ...

# %%
##plt.plot(df2.MONTH, df2.PH)
plt.plot(july.INTERNAL_TEMP, july.EXTERNAL_TEMP)
plt.plot(nov.INTERNAL_TEMP, nov.EXTERNAL_TEMP)
plt.legend(['july','nov'])
plt.xlabel('INTERNAL_TEMP')
plt.ylabel('EXTERNAL_TEMP')
plt.show()

# %%
df2=df.head(1000)
df2
# Out:
#      MONTH  DAY  HOUR  MINUTE  SECOND CARBON_MONOXIDE  INTERNAL_TEMP  \
# 0      6.0   18    14    30.0    43.0             201           25.0
# 1      6.0   18    14    30.0    48.0             201           25.0
# 2      6.0   18    14    31.0     3.0             201           25.0
# 3      6.0   18    14    31.0     8.0             201           25.0
# 4      6.0   18    14    31.0    13.0             201           25.0
# ..     ...  ...   ...     ...     ...             ...            ...
# 995    6.0   18    16    18.0    39.0             196           31.0
# 996    6.0   18    16    18.0    49.0             196           31.0
# 997    6.0   18    16    18.0    54.0             196           31.0
# 998    6.0   18    16    18.0    59.0             196           31.0
# 999    6.0   18    16    19.0     9.0             196           31.0
#
#      EXTERNAL_TEMP  HUMIDITY  LIGHT INTENSITY    PH
# 0             29.0      95.0            27.19  4.39
# ...

# %%
plt.plot(df2.PH, df2.CARBON_MONOXIDE)
plt.plot(df2.PH, df2.HUMIDITY)
plt.legend(['CARBON_MONOXIDE','Humidity '])
plt.xlabel('PH')
plt.ylabel('Humidity & Carbon-monoxide')
plt.show()
